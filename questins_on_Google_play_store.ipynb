# %% [markdown]
# <a href="https://colab.research.google.com/github/MinakshiLute/Our-play-store-analysis-project-KMNGY/blob/main/questins_on_Google_play_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/Play Store Data.csv"
play_data = pd.read_csv(file_path)
print(play_data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
file_path1 = "/content/User Reviews.csv"
user_data = pd.read_csv(file_path,index_col ='App')
print(user_data)
# Out:
#                                                                Category  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook           ART_AND_DESIGN
# Coloring book moana                                      ART_AND_DESIGN
# U Launcher Lite – FREE Live Cool Themes, Hide Apps       ART_AND_DESIGN
# Sketch - Draw & Paint                                    ART_AND_DESIGN
# Pixel Draw - Number Art Coloring Book                    ART_AND_DESIGN
# ...                                                                 ...
# Sya9a Maroc - FR                                                 FAMILY
# Fr. Mike Schmitz Audio Teachings                                 FAMILY
# Parkinson Exercices FR                                          MEDICAL
# The SCP Foundation DB fr nn5n                       BOOKS_AND_REFERENCE
# iHoroscope - 2018 Daily Horoscope & Astrology                 LIFESTYLE
#
#                                                     Rating Reviews  \
# App
# ...

# %% [markdown]
# Ques:1 **How much Paid and how much Free?**

# %%
free_paid = play_data['Type'].value_counts().reset_index()
plt.figure(figsize=(12,10))
colors = ['red','blue']
plt.pie(x=free_paid['Type'], labels = free_paid['index'], colors=colors, autopct = '%.2f%%', textprops = {'fontsize':15})
plt.title('free vs paid app')
plt.legend()

# %% [markdown]
# Ques:3 **Which categories have most Paid Vs Free?**

# %%
category_count = play_data.groupby(['Category','Type']).count()['App'].unstack()
category_count.plot(kind ='bar',stacked=True)
plt.title("Distribution of Free Vs. Paid App by Category")
plt.xlabel("Category")
plt.ylabel("Number Of Apps")
plt.show()

# %% [markdown]
# Ques 7 which Category of App related to 'Content Rating' is more?

# %%
c = play_data['Content Rating'].value_counts().reset_index()
plt.figure(figsize=(12,10))
colors = ['red','blue','green','yellow','gold','orange']
plt.pie(x=free_paid['Content Rating'], labels = free_paid['index'], colors=colors, autopct = '%.2f%%', textprops = {'fontsize':15})
plt.title('free vs paid app')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Content Rating'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# Ques:8 which category getting higest Rating

# %%
play_data.groupby('Category')['Rating'].mean().sort_values(ascending= False)
x = play_data['Category']
y = play_data['Rating']
plt.bar(x,y)
plt.xticks(rotation = 45 , ha = 'right', fontsize=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d76c98c00bf6> in <cell line: 1>()
# ----> 1 play_data.groupby('Category')['Rating'].mean().sort_values(ascending= False)
#       2 x = play_data['Category']
#       3 y = play_data['Rating']
#       4 plt.bar(x,y)
#       5 plt.xticks(rotation = 45 , ha = 'right', fontsize=10)
#
# NameError: name 'play_data' is not defined
